# %%
import pandas as pd
from pandas import set_option
from pandas import DataFrame

import numpy as np

import tensorflow as tf
from tensorflow import keras

import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from keras.layers import Dropout

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.metrics import accuracy_score
from scikeras.wrappers import KerasClassifier
from pickle import dump
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import KFold
import keras_tuner as kt
from sklearn.metrics import confusion_matrix, classification_report

import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
# Out:
# 2023-02-04 18:07:57.178395: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-04 18:07:57.485007: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-04 18:07:57.485043: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-04 18:07:58.671946: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-02-04 18:07:58.672037: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-02-04 18:07:58.672047: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
to_keep = [i for i in range(0, 519)]
data = pd.read_csv('METABRIC_RNA_Mutation.csv', header=0, usecols=to_keep)
print(data.shape)
# Out:
# (1904, 519)

# %%
# Define class for the classification class "death_from_cancer"
data['death_from_cancer'].replace({'Living': 0, 'Died of Other Causes': 1, 'Died of Disease': 2}, inplace=True)

# %%
# Imputation of missing values with 'mode' values in important columns
cols_to_fill = ["type_of_breast_surgery", "cancer_type_detailed", "cellularity", "er_status_measured_by_ihc", 
                "neoplasm_histologic_grade", "tumor_other_histologic_subtype", "primary_tumor_laterality", 
                "mutation_count", "3-gene_classifier_subtype", "tumor_size", "tumor_stage"]
for col in cols_to_fill:
    data[col] = data[col].fillna(data[col].mode()[0])

# %%
df = data.copy(deep = True)

# Convert strings into categorial classes
cols_to_convert = ["type_of_breast_surgery", "cellularity", "er_status_measured_by_ihc", "her2_status",
                 "inferred_menopausal_state","pr_status"]

replace_dict = {"type_of_breast_surgery": {'BREAST CONSERVING': 1, 'MASTECTOMY': 0},
                "cellularity": {'High': 2, 'Moderate': 1, 'Low': 0},
                "er_status_measured_by_ihc": {'Positve': 1, 'Negative': 0},
                "her2_status": {'Positive': 1, 'Negative': 0},
                "inferred_menopausal_state": {'Post': 1, 'Pre': 0},
                "pr_status": {'Positive': 1, 'Negative': 0}}

for col in cols_to_convert:
    df[col].replace(replace_dict[col], inplace=True)

# %%
#Use One Hot Encoding to convert categorical features into numeric features

df = pd.get_dummies(data = df, columns = ['cancer_type','cancer_type_detailed', 'er_status', 'her2_status_measured_by_snp6', 'pam50_+_claudin-low_subtype','tumor_other_histologic_subtype', 'integrative_cluster', 'primary_tumor_laterality', '3-gene_classifier_subtype'])

# %%
# drop rows with missing values
df.dropna(inplace=True)
print(df.shape)
# Out:
# (1888, 556)

# %%
# b) Feature Selection
# Select the top k most relevant features (largest values)
def select_features(X, y, features):
# configure to select all features
    fs = SelectKBest(score_func=f_classif, k=10)
    
# learn relationship from training data
    fs.fit(X, y)
    
    df_scores = pd.DataFrame(fs.scores_)
    df_columns = pd.DataFrame(X.columns)
    
    feature_scores = pd.concat([df_columns,df_scores], axis=1)
    feature_scores.columns = ['fname','score']
    
    best_features = feature_scores.nlargest(features,'score')
    
    X_featured = pd.DataFrame()  
    for j in best_features['fname']:
        X_featured[j] = X[j]

    X = X_featured.copy()
    #X = np.array(X)    
    #y = np.array(y)
    
    # plot feature scores
    a = best_features['fname']
    b= best_features['score']    
    plt.bar(a, b)
    plt.xticks(rotation=45, ha='right')
    plt.show()
    return X, y, fs

# %%
# c) Split the dataset into train and test sets 
X = df.drop(columns=['death_from_cancer', 'patient_id', 'oncotree_code'], axis = 1)
y = df['death_from_cancer']

X, y, fs = select_features(X, y, 20)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
# Out:
# /home/haziqfaiz/.local/lib/python3.10/site-packages/sklearn/feature_selection/_univariate_selection.py:113: RuntimeWarning: divide by zero encountered in divide
#   f = msb / msw

# %%
# c) Data Transforms
# Standardize the dataset by rescaling the distribution of values
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# convert the array back to a dataframe
X_train = DataFrame(X_train)
X_test = DataFrame(X_test)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (1416, 20) (472, 20)
# (1416,) (472,)

# %% [markdown]
# # Neural network with 1 hidden layer.

# %%
NN_model_1 = keras.Sequential([    
    keras.layers.Dense(300, input_shape = (20, ), activation = 'relu'),
    keras.layers.Dropout(0.4),
    keras.layers.Dense(1, activation='softplus')  
])

NN_model_1.compile(optimizer = 'adam',
                loss = 'mean_squared_logarithmic_error',
                metrics=['mse'])
# Out:
# 2023-02-04 18:08:13.428224: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-02-04 18:08:13.428256: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-04 18:08:13.428299: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (fedora): /proc/driver/nvidia/version does not exist
# 2023-02-04 18:08:13.428587: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# fit the keras model on the dataset
model_1_fit = NN_model_1.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 1s 12ms/step - loss: 0.1814 - mse: 0.6336 - val_loss: 0.1264 - val_mse: 0.4811
# Epoch 2/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0978 - mse: 0.3643 - val_loss: 0.0689 - val_mse: 0.2780
# Epoch 3/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0574 - mse: 0.2362 - val_loss: 0.0435 - val_mse: 0.2024
# Epoch 4/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0398 - mse: 0.1881 - val_loss: 0.0319 - val_mse: 0.1609
# Epoch 5/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0334 - mse: 0.1705 - val_loss: 0.0280 - val_mse: 0.1421
# Epoch 6/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0287 - mse: 0.1555 - val_loss: 0.0248 - val_mse: 0.1390
# Epoch 7/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0270 - mse: 0.1512 - val_loss: 0.0247 - val_mse: 0.1461
# Epoch 8/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0250 - mse: 0.1425 - val_loss: 0.0228 - val_mse: 0.1325
# Epoch 9/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0231 - mse: 0.1330 - val_loss: 0.0242 - val_mse: 0.1465
# Epoch 10/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0245 - mse: 0.1437 - val_loss: 0.0216 - val_mse: 0.1282
# Epoch 11/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0235 - mse: 0.1383 - val_loss: 0.0210 - val_mse: 0.1211
# Epoch 12/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0230 - mse: 0.1356 - val_loss: 0.0207 - val_mse: 0.1210
# Epoch 13/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0223 - mse: 0.1330 - val_loss: 0.0208 - val_mse: 0.1219
# Epoch 14/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0229 - mse: 0.1369 - val_loss: 0.0217 - val_mse: 0.1325
# Epoch 15/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0225 - mse: 0.1347 - val_loss: 0.0210 - val_mse: 0.1274
# Epoch 16/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0215 - mse: 0.1288 - val_loss: 0.0205 - val_mse: 0.1250
# Epoch 17/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0203 - mse: 0.1224 - val_loss: 0.0203 - val_mse: 0.1216
# Epoch 18/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0205 - mse: 0.1235 - val_loss: 0.0201 - val_mse: 0.1217
# Epoch 19/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0197 - mse: 0.1191 - val_loss: 0.0200 - val_mse: 0.1203
# Epoch 20/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0206 - mse: 0.1251 - val_loss: 0.0199 - val_mse: 0.1190
# Epoch 21/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0202 - mse: 0.1228 - val_loss: 0.0197 - val_mse: 0.1209
# Epoch 22/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0194 - mse: 0.1182 - val_loss: 0.0197 - val_mse: 0.1206
# Epoch 23/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0211 - mse: 0.1283 - val_loss: 0.0196 - val_mse: 0.1200
# Epoch 24/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0199 - mse: 0.1208 - val_loss: 0.0194 - val_mse: 0.1183
# Epoch 25/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0200 - mse: 0.1215 - val_loss: 0.0195 - val_mse: 0.1190
# Epoch 26/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0186 - mse: 0.1142 - val_loss: 0.0210 - val_mse: 0.1244
# Epoch 27/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0195 - mse: 0.1187 - val_loss: 0.0192 - val_mse: 0.1169
# Epoch 28/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0188 - mse: 0.1154 - val_loss: 0.0191 - val_mse: 0.1161
# Epoch 29/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0180 - mse: 0.1097 - val_loss: 0.0194 - val_mse: 0.1198
# Epoch 30/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0181 - mse: 0.1111 - val_loss: 0.0196 - val_mse: 0.1223
# Epoch 31/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0182 - mse: 0.1128 - val_loss: 0.0191 - val_mse: 0.1175
# Epoch 32/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0181 - mse: 0.1111 - val_loss: 0.0195 - val_mse: 0.1172
# Epoch 33/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0179 - mse: 0.1101 - val_loss: 0.0193 - val_mse: 0.1160
# Epoch 34/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0180 - mse: 0.1102 - val_loss: 0.0189 - val_mse: 0.1161
# Epoch 35/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0182 - mse: 0.1115 - val_loss: 0.0188 - val_mse: 0.1146
# Epoch 36/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0181 - mse: 0.1117 - val_loss: 0.0191 - val_mse: 0.1146
# Epoch 37/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0179 - mse: 0.1092 - val_loss: 0.0187 - val_mse: 0.1148
# Epoch 38/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0176 - mse: 0.1083 - val_loss: 0.0192 - val_mse: 0.1166
# Epoch 39/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0177 - mse: 0.1093 - val_loss: 0.0192 - val_mse: 0.1160
# Epoch 40/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0168 - mse: 0.1042 - val_loss: 0.0189 - val_mse: 0.1179
# Epoch 41/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0174 - mse: 0.1085 - val_loss: 0.0189 - val_mse: 0.1160
# Epoch 42/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0173 - mse: 0.1069 - val_loss: 0.0192 - val_mse: 0.1171
# Epoch 43/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0165 - mse: 0.1016 - val_loss: 0.0188 - val_mse: 0.1151
# Epoch 44/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0169 - mse: 0.1049 - val_loss: 0.0190 - val_mse: 0.1162
# Epoch 45/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0173 - mse: 0.1067 - val_loss: 0.0195 - val_mse: 0.1177
# Epoch 46/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0175 - mse: 0.1084 - val_loss: 0.0189 - val_mse: 0.1156
# Epoch 47/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0164 - mse: 0.1015 - val_loss: 0.0194 - val_mse: 0.1177
# Epoch 48/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0166 - mse: 0.1025 - val_loss: 0.0189 - val_mse: 0.1169
# Epoch 49/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0184 - mse: 0.1137 - val_loss: 0.0188 - val_mse: 0.1171
# Epoch 50/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0171 - mse: 0.1060 - val_loss: 0.0191 - val_mse: 0.1156

# %%
# Plot learning curve
plt.figure(figsize = (10, 5))
plt.plot(model_1_fit.history['mse'], label = 'training')
plt.plot(model_1_fit.history['val_mse'], label = 'validation')
plt.xlabel('epochs')
plt.ylabel('mse')
plt.title('Model 1 Loss vs Epoch')
plt.legend()

# %%
predictions_1=(NN_model_1.predict(X_test)).astype("int32")
# Out:
# 15/15 [==============================] - 0s 1ms/step

# %%
cm = confusion_matrix(predictions_1,y_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %%
print(accuracy_score(y_test, predictions_1))
print(classification_report(y_test, predictions_1))
# Out:
# 0.711864406779661
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99       195
#          1.0       0.47      0.95      0.63       123
#          2.0       0.89      0.16      0.27       154
#
#     accuracy                           0.71       472
#    macro avg       0.78      0.70      0.63       472
# weighted avg       0.82      0.71      0.66       472

# %% [markdown]
# # Hyperparameter tuning with Hyper Band.

# %%
def model_builder(hp):
    model = keras.Sequential()
  

    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
    model.add(keras.layers.Dense(units=hp_units, input_shape = (20, ), activation = 'relu'))
    model.add(keras.layers.Dropout(0.4))
    model.add(keras.layers.Dense(1, activation='softplus'))

    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss='mean_squared_logarithmic_error',
                metrics=['mse'])

    return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective='mse',
                     max_epochs=50,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(X_train, y_train, epochs=50,batch_size=64)

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 192 and the optimal learning rate for the optimizer
# is 0.01.

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)

val_acc_per_epoch = history.history['mse']
best_epoch = val_acc_per_epoch.index(min(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/50
# /home/haziqfaiz/.local/lib/python3.10/site-packages/keras/engine/data_adapter.py:1696: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 36/36 [==============================] - 1s 5ms/step - loss: 0.0670 - mse: 0.2929 - val_loss: 0.0247 - val_mse: 0.1474
# Epoch 2/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0274 - mse: 0.1636 - val_loss: 0.0207 - val_mse: 0.1248
# Epoch 3/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0234 - mse: 0.1414 - val_loss: 0.0205 - val_mse: 0.1304
# Epoch 4/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0223 - mse: 0.1373 - val_loss: 0.0192 - val_mse: 0.1188
# Epoch 5/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0210 - mse: 0.1299 - val_loss: 0.0189 - val_mse: 0.1161
# Epoch 6/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0208 - mse: 0.1289 - val_loss: 0.0190 - val_mse: 0.1195
# Epoch 7/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0191 - mse: 0.1186 - val_loss: 0.0184 - val_mse: 0.1129
# Epoch 8/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0198 - mse: 0.1235 - val_loss: 0.0183 - val_mse: 0.1126
# Epoch 9/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0198 - mse: 0.1227 - val_loss: 0.0185 - val_mse: 0.1121
# Epoch 10/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0191 - mse: 0.1189 - val_loss: 0.0185 - val_mse: 0.1164
# Epoch 11/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0188 - mse: 0.1164 - val_loss: 0.0186 - val_mse: 0.1183
# Epoch 12/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0210 - mse: 0.1337 - val_loss: 0.0184 - val_mse: 0.1152
# Epoch 13/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0191 - mse: 0.1194 - val_loss: 0.0206 - val_mse: 0.1233
# Epoch 14/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0203 - mse: 0.1270 - val_loss: 0.0208 - val_mse: 0.1239
# Epoch 15/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0182 - mse: 0.1143 - val_loss: 0.0181 - val_mse: 0.1108
# Epoch 16/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0180 - mse: 0.1119 - val_loss: 0.0187 - val_mse: 0.1180
# Epoch 17/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0183 - mse: 0.1137 - val_loss: 0.0190 - val_mse: 0.1214
# Epoch 18/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0177 - mse: 0.1105 - val_loss: 0.0186 - val_mse: 0.1118
# Epoch 19/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0175 - mse: 0.1086 - val_loss: 0.0178 - val_mse: 0.1095
# Epoch 20/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0178 - mse: 0.1110 - val_loss: 0.0181 - val_mse: 0.1109
# Epoch 21/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0176 - mse: 0.1096 - val_loss: 0.0184 - val_mse: 0.1110
# Epoch 22/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0178 - mse: 0.1113 - val_loss: 0.0187 - val_mse: 0.1123
# Epoch 23/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0177 - mse: 0.1106 - val_loss: 0.0179 - val_mse: 0.1093
# Epoch 24/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0177 - mse: 0.1103 - val_loss: 0.0187 - val_mse: 0.1143
# Epoch 25/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0171 - mse: 0.1067 - val_loss: 0.0179 - val_mse: 0.1138
# Epoch 26/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0173 - mse: 0.1092 - val_loss: 0.0185 - val_mse: 0.1118
# Epoch 27/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0175 - mse: 0.1089 - val_loss: 0.0182 - val_mse: 0.1108
# Epoch 28/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0177 - mse: 0.1104 - val_loss: 0.0183 - val_mse: 0.1092
# Epoch 29/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0175 - mse: 0.1080 - val_loss: 0.0186 - val_mse: 0.1183
# Epoch 30/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0165 - mse: 0.1025 - val_loss: 0.0184 - val_mse: 0.1107
# Epoch 31/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0169 - mse: 0.1043 - val_loss: 0.0182 - val_mse: 0.1163
# Epoch 32/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0168 - mse: 0.1048 - val_loss: 0.0175 - val_mse: 0.1071
# Epoch 33/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0162 - mse: 0.1007 - val_loss: 0.0184 - val_mse: 0.1138
# Epoch 34/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0170 - mse: 0.1058 - val_loss: 0.0178 - val_mse: 0.1086
# Epoch 35/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0162 - mse: 0.1011 - val_loss: 0.0176 - val_mse: 0.1091
# Epoch 36/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0160 - mse: 0.0992 - val_loss: 0.0183 - val_mse: 0.1150
# Epoch 37/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0168 - mse: 0.1041 - val_loss: 0.0179 - val_mse: 0.1097
# Epoch 38/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0162 - mse: 0.0995 - val_loss: 0.0174 - val_mse: 0.1076
# Epoch 39/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0165 - mse: 0.1025 - val_loss: 0.0181 - val_mse: 0.1115
# Epoch 40/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0166 - mse: 0.1030 - val_loss: 0.0176 - val_mse: 0.1096
# Epoch 41/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0166 - mse: 0.1031 - val_loss: 0.0176 - val_mse: 0.1084
# Epoch 42/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0167 - mse: 0.1044 - val_loss: 0.0185 - val_mse: 0.1171
# Epoch 43/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0170 - mse: 0.1061 - val_loss: 0.0176 - val_mse: 0.1059
# Epoch 44/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0166 - mse: 0.1030 - val_loss: 0.0179 - val_mse: 0.1107
# Epoch 45/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0166 - mse: 0.1024 - val_loss: 0.0180 - val_mse: 0.1126
# Epoch 46/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0166 - mse: 0.1033 - val_loss: 0.0188 - val_mse: 0.1133
# Epoch 47/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0172 - mse: 0.1069 - val_loss: 0.0185 - val_mse: 0.1114
# Epoch 48/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0168 - mse: 0.1041 - val_loss: 0.0182 - val_mse: 0.1138
# Epoch 49/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0163 - mse: 0.1014 - val_loss: 0.0189 - val_mse: 0.1194
# Epoch 50/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0175 - mse: 0.1087 - val_loss: 0.0187 - val_mse: 0.1211
# Best epoch: 36

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hypermodel_fit=hypermodel.fit(X_train, y_train, epochs=best_epoch,validation_data=(X_test,y_test),batch_size=64)
# Out:
# Epoch 1/36
# 23/23 [==============================] - 1s 7ms/step - loss: 0.0777 - mse: 0.3285 - val_loss: 0.0361 - val_mse: 0.2197
# Epoch 2/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0318 - mse: 0.1948 - val_loss: 0.0239 - val_mse: 0.1438
# Epoch 3/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0250 - mse: 0.1480 - val_loss: 0.0206 - val_mse: 0.1219
# Epoch 4/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0237 - mse: 0.1434 - val_loss: 0.0196 - val_mse: 0.1187
# Epoch 5/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0202 - mse: 0.1249 - val_loss: 0.0203 - val_mse: 0.1260
# Epoch 6/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0203 - mse: 0.1258 - val_loss: 0.0233 - val_mse: 0.1485
# Epoch 7/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0207 - mse: 0.1284 - val_loss: 0.0193 - val_mse: 0.1177
# Epoch 8/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0203 - mse: 0.1262 - val_loss: 0.0193 - val_mse: 0.1176
# Epoch 9/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0197 - mse: 0.1214 - val_loss: 0.0194 - val_mse: 0.1216
# Epoch 10/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0193 - mse: 0.1198 - val_loss: 0.0192 - val_mse: 0.1176
# Epoch 11/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0182 - mse: 0.1142 - val_loss: 0.0220 - val_mse: 0.1327
# Epoch 12/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0196 - mse: 0.1218 - val_loss: 0.0190 - val_mse: 0.1176
# Epoch 13/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0186 - mse: 0.1163 - val_loss: 0.0190 - val_mse: 0.1158
# Epoch 14/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0201 - mse: 0.1253 - val_loss: 0.0197 - val_mse: 0.1256
# Epoch 15/36
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0192 - mse: 0.1200 - val_loss: 0.0203 - val_mse: 0.1245
# Epoch 16/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0188 - mse: 0.1172 - val_loss: 0.0199 - val_mse: 0.1268
# Epoch 17/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0196 - mse: 0.1216 - val_loss: 0.0200 - val_mse: 0.1270
# Epoch 18/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0184 - mse: 0.1156 - val_loss: 0.0195 - val_mse: 0.1183
# Epoch 19/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0184 - mse: 0.1136 - val_loss: 0.0191 - val_mse: 0.1202
# Epoch 20/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0184 - mse: 0.1150 - val_loss: 0.0193 - val_mse: 0.1183
# Epoch 21/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0180 - mse: 0.1124 - val_loss: 0.0204 - val_mse: 0.1252
# Epoch 22/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0184 - mse: 0.1159 - val_loss: 0.0196 - val_mse: 0.1214
# Epoch 23/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0176 - mse: 0.1103 - val_loss: 0.0194 - val_mse: 0.1229
# Epoch 24/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0180 - mse: 0.1132 - val_loss: 0.0193 - val_mse: 0.1196
# Epoch 25/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0173 - mse: 0.1076 - val_loss: 0.0195 - val_mse: 0.1205
# Epoch 26/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0168 - mse: 0.1043 - val_loss: 0.0191 - val_mse: 0.1187
# Epoch 27/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0182 - mse: 0.1138 - val_loss: 0.0189 - val_mse: 0.1186
# Epoch 28/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0171 - mse: 0.1070 - val_loss: 0.0199 - val_mse: 0.1223
# Epoch 29/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0175 - mse: 0.1091 - val_loss: 0.0206 - val_mse: 0.1263
# Epoch 30/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0178 - mse: 0.1104 - val_loss: 0.0194 - val_mse: 0.1210
# Epoch 31/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0166 - mse: 0.1037 - val_loss: 0.0196 - val_mse: 0.1226
# Epoch 32/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0173 - mse: 0.1082 - val_loss: 0.0195 - val_mse: 0.1211
# Epoch 33/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0167 - mse: 0.1040 - val_loss: 0.0194 - val_mse: 0.1215
# Epoch 34/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0175 - mse: 0.1097 - val_loss: 0.0197 - val_mse: 0.1227
# Epoch 35/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0172 - mse: 0.1078 - val_loss: 0.0195 - val_mse: 0.1215
# Epoch 36/36
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0169 - mse: 0.1052 - val_loss: 0.0205 - val_mse: 0.1274

# %%
# Plot learning curve
plt.figure(figsize = (10, 5))
plt.plot(hypermodel_fit.history['mse'], label = 'training')
plt.plot(hypermodel_fit.history['val_mse'], label = 'validation')
plt.xlabel('epochs')
plt.ylabel('mse')
plt.title('Model 1 Loss vs Epoch')
plt.legend()

# %%
predictions_hyper=(hypermodel.predict(X_test)).astype("int32")
# Out:
# 15/15 [==============================] - 0s 1ms/step

# %%
cm = confusion_matrix(y_test,predictions_hyper)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %%
print(accuracy_score(y_test, predictions_hyper))
print(classification_report(y_test, predictions_hyper))
# Out:
# 0.7415254237288136
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       195
#          1.0       0.50      0.95      0.66       123
#          2.0       0.86      0.25      0.38       154
#
#     accuracy                           0.74       472
#    macro avg       0.79      0.73      0.68       472
# weighted avg       0.83      0.74      0.71       472

# %%
hypermodel.save('hyper_model')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 hypermodel.save()
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# TypeError: Model.save() missing 1 required positional argument: 'filepath'

# %% [markdown]
# ## Hyper Parameter tuning with Hyper Band with 2 hidden layers.

# %%
def model_builder(hp):
    model = keras.Sequential()
  

    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units1 = hp.Int('units1', min_value=32, max_value=512, step=32)
    hp_units2 = hp.Int('units2', min_value=32, max_value=512, step=32)
    model.add(keras.layers.Dense(units=hp_units1, input_shape = (20, ), activation = 'relu'))
    model.add(keras.layers.Dropout(0.4))
    model.add(keras.layers.Dense(units=hp_units2, activation = 'relu'))
    model.add(keras.layers.Dropout(0.4))
    model.add(keras.layers.Dense(1, activation='softplus'))

    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss='mean_squared_logarithmic_error',
                metrics=['mse'])

    return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective='mse',
                     max_epochs=50,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')

# %%
tuner.search(X_train, y_train, epochs=50,batch_size=64)

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')}, the optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 192, the optimal number of units in the first densely-connected
# layer is 192 and the optimal learning rate for the optimizer
# is 0.01.
